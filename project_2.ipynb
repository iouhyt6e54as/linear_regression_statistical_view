# %%
import pandas as pd

# %%
from linear_regression_statistical_view import (
    LinearRegressionStatisticalView,
    compare
)

# %%
# Read Data
df = pd.read_csv("cleaned_kc_house_data.csv")
print(df.columns)
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'view',
#        'condition', 'grade', 'sqft_above', 'sqft_basement', 'zipcode', 'lat',
#        'long', 'sqft_living15', 'sqft_lot15', 'year', 'month', 'total_sqft',
#        'house_age', 'was_renovated', 'age_since_renovation', 'waterfront_0',
#        'waterfront_1', 'price'],
#       dtype='str')

# %%
X = df["sqft_living"]
Y = df["price"]

# %%
# Run The Model
model = LinearRegressionStatisticalView(alpha=0.05)
model.fit(X, Y)

# %%
print(model.summary())
# Out:
# {'f_critical': 3.8419967717543915, 'f_stat': 16912.575931207855, 'beta_confidence_intervals': {'beta_0': (np.float64(533504.4982082819), np.float64(541005.9755916024)), 'beta_1': (np.float64(245102.43882803363), np.float64(252603.91621135408))}, 'degrees_of_freedom': {'df_model': 1, 'df_resid': 17288, 'df_total': 17289}, 'r_squareddef': 0.4945114364514316, 'r': 0.7032150712630039}

# %%
result = compare(
    df,
    "sqft_living",
    "bedrooms",
    "price"
)

print(result)
# Out:
# {'predictor_1': 'sqft_living', 'predictor_2': 'bedrooms', 'f_stat_1': 16912.575931207855, 'f_stat_2': 1966.439586645513, 'best_predictor': 'sqft_living'}
